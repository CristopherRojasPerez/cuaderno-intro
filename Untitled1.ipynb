# %% [markdown]
# <a href="https://colab.research.google.com/github/CristopherRojasPerez/cuaderno-intro/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## semana2

# %% [markdown]
# Ejercicio 1
#
# para sacar promedio se numan n1+n2+n3+n4 y luego se divide entre 4

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
#
#
# ```
# Algoritmo Promedio
# 	Leer N1
# 	Leer N2
# 	Leer N3
# 	Leer N4
# 	resultado = N1+N2+N3+N4
# 	Escribir resultado/4
# FinAlgoritmo
# ```
#
#
# ```
# def ejercicio1():
#     numero1=input("introduzca numero1")
#     numero2=input("introduzca numero2")
#     numero3=input("introduzca numero3")
#     numero4=input("introduzca numero4")
#     suma = mumero1 + numero2 + numero3 + numero4
#     promedio = suma/4
#     print("promedio")
# ```

# %% [markdown]
# Ejercicio 2
#
# ![image.png](`data:image/png;base64,...`)
#
#
#
# ```
# Algoritmo volumenCaja
# 	Leer ancho
# 	Leer altura
# 	Leer largo
# 	volumen = altura*ancho*largo
# 	Escribir volumen
# FinAlgoritmo
#
# ```
#
#
#
# ```
# def ejercicio2():
#     altura=input("ingrese altura")
#     ancho=input("ingrese ancho")
#     largo=input("ingrese largo")
#     volumen = altura*ancho*largo
#     print(volumen)
#
# ```

# %% [markdown]
# Ejercicio 3
# ![image.png](data:image/png;base64,...)
#
#
#
# ```
# Algoritmo circunferencia_
# 	Leer r
# 	p = 3.14
# 	radio = r*r
# 	circunferencia = p*radio
# 	Escribir circunferencia
# FinAlgoritmo
# ```
#
#
#
# ```
# def ejercicio3():
#     radio= int(input("inserte el radio"))
#     pi = 3.14
#     circunferencia = pi * radio ** 2
#     print(circunferencia)
# ```

# %% [markdown]
# ejercicio 6
# ![image.png](data:image/png;base64,...)
#
#
#
# ```
# Algoritmo votaciones
# 	Leer edad
# 	Si edad>=18 Entonces
# 		Escribir "Puede votar"
# 	SiNo
# 		Escribir "no puede"
# 	FinSi
# FinAlgoritmo
#
# ```
#
#
# ```
# def ejercicio4():
#     edad=input("ingrese edad")
#     if edad >= 18:
#         return ("Puede votar")
#     else:
#         return("No puede votar")
# ```
